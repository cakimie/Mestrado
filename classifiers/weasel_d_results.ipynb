# %% [markdown]
# # Weasel-D

# %% [markdown]
# Country: 0
#
# City: 0

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data provided
metrics = ['accuracy_score', 'f1_score', 'precision_score', 'recall_score']
means = [0.7860229, 0.7750206, 0.7723335, 0.7860229]
stds = [0.0214483, 0.0223657, 0.0219168, 0.0214483]
t_interval_0 = [0.7264728423, 0.7129235441, 0.7114828102, 0.7264728423]
t_interval_1 = [0.8455729869, 0.8371175878, 0.833184236, 0.8455729869]

# Calculate the error bars
errors = [t1 - t0 for t0, t1 in zip(t_interval_0, t_interval_1)]

x = np.arange(len(metrics))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(10, 6))
rects = ax.bar(x, means, width, label='Country 0 City 0', yerr=errors, capsize=5)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Metrics')
ax.set_ylabel('Scores')
ax.set_title('Scores by metric Country 0 City 0')
ax.set_xticks(x)
ax.set_xticklabels(metrics)
ax.legend()

# Function to add labels on bars
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(round(height, 3)),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects)

fig.tight_layout()

plt.show()

# %% [markdown]
# Country: 0
#
# City: 1

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data provided
metrics = ['accuracy_score', 'f1_score', 'precision_score', 'recall_score']
means = [0.7077301,	0.7025909, 0.7067849, 0.7077301]
stds = [0.0421701, 0.0445236, 0.0479883, 0.0421701]
t_intervals = [(0.5906472596, 0.8248130034), (0.5789734706, 0.8262083242), (0.5735479493, 0.8400218995), (0.5906472596, 0.8248130034)]

# Calculate the error bars (using the confidence interval as error)
errors = [(upper - mean) for mean, (lower, upper) in zip(means, t_intervals)]

x = np.arange(len(metrics))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(10, 6))
rects1 = ax.bar(x, means, width, label='Country 0 City 1', yerr=errors, capsize=5)

# Add some text for labels, title, and custom x-axis tick labels, etc.
ax.set_xlabel('Metrics')
ax.set_ylabel('Scores')
ax.set_title('Scores by metric Country 0 City 1')
ax.set_xticks(x)
ax.set_xticklabels(metrics)
ax.legend()

# Function to add labels on bars
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(round(height, 3)),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)

fig.tight_layout()

plt.show()

# %% [markdown]
# Country: 0
#
# City: 2

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data provided
metrics = ['accuracy_score', 'f1_score', 'precision_score', 'recall_score']
means = [0.7549491, 0.7494852, 0.7520444, 0.7549491]
stds = [0.0220701, 0.0233196, 0.0210119, 0.0220701]
t_interval_0 = [0.6936725353, 0.6847396615, 0.6937058849, 0.6936725353]
t_interval_1 = [0.816225608, 0.8142308319, 0.8103828623, 0.816225608]

# Calculate the error bars
errors = [t1 - t0 for t0, t1 in zip(t_interval_0, t_interval_1)]

x = np.arange(len(metrics))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(10, 6))
rects = ax.bar(x, means, width, label='Country 0 City 2', yerr=errors, capsize=5)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Metrics')
ax.set_ylabel('Scores')
ax.set_title('Scores by metric Country 0 City 2')
ax.set_xticks(x)
ax.set_xticklabels(metrics)
ax.legend()

# Function to add labels on bars
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(round(height, 3)),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects)

fig.tight_layout()

plt.show()

# %% [markdown]
# Country: 1
#
# City: 0

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data provided
metrics = ['accuracy_score', 'f1_score', 'precision_score', 'recall_score']
means = [0.7050824, 0.7014499, 0.7058068, 0.7050824]
stds = [0.019814, 0.0194728, 0.0185834, 0.019814]
t_intervals = [(0.6500700672, 0.7600947968), (0.6473846815, 0.7555151991), (0.6542110246, 0.7574024973), (0.6500700672, 0.7600947968)]

# Calculate the error bars (using the confidence interval as error)
errors = [(upper - mean) for mean, (lower, upper) in zip(means, t_intervals)]

x = np.arange(len(metrics))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(10, 6))
rects1 = ax.bar(x, means, width, label='Country 1 City 0', yerr=errors, capsize=5)

# Add some text for labels, title, and custom x-axis tick labels, etc.
ax.set_xlabel('Metrics')
ax.set_ylabel('Scores')
ax.set_title('Scores by metric Country 1 City 0')
ax.set_xticks(x)
ax.set_xticklabels(metrics)
ax.legend()

# Function to add labels on bars
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(round(height, 3)),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)

fig.tight_layout()

plt.show()

# %% [markdown]
# Country: 1
#
# City: 2

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data provided
metrics = ['accuracy_score', 'f1_score', 'precision_score', 'recall_score']
means = [0.6748362, 0.6710036, 0.677202, 0.6748362]
stds = [0.0198673, 0.019282, 0.0204394, 0.0198673]
t_intervals = [
    (0.6196756265, 0.7299967761),
    (0.6174680948, 0.7245390294),
    (0.6204530188, 0.7339510099),
    (0.6196756265, 0.7299967761)
]

# Calculate the error bars (using confidence intervals as error)
errors = [(t1 - m, m - t0) for m, (t0, t1) in zip(means, t_intervals)]
errors = np.array(errors).T  # Transpose to separate lower and upper errors

x = np.arange(len(metrics))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(10, 6))
rects = ax.bar(x, means, width, label='Country 1 City 2', yerr=errors, capsize=5)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Metrics')
ax.set_ylabel('Scores')
ax.set_title('Scores by metric Country 1 City 2')
ax.set_xticks(x)
ax.set_xticklabels(metrics)
ax.legend()

# Function to add labels on bars
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(round(height, 3)),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects)

fig.tight_layout()

plt.show()

# %% [markdown]
# Country: 1
#
# City: 4

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data provided
metrics = ['accuracy_score', 'f1_score', 'precision_score', 'recall_score']
means = [0.6793103, 0.6604772, 0.6836487, 0.6793103]
stds = [0.0187587, 0.0222506, 0.0272602, 0.0187587]
t_interval_0 = [0.6272279322, 0.5986997122, 0.6079621818, 0.6272279322]
t_interval_1 = [0.7313927574, 0.7222546386, 0.7593352203, 0.7313927574]

# Calculate the error bars (difference between mean and confidence interval)
errors = [(t1 - m, m - t0) for m, t0, t1 in zip(means, t_interval_0, t_interval_1)]
errors = np.array(errors).T  # Transpose to separate positive and negative errors

x = np.arange(len(metrics))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(10, 6))
rects = ax.bar(x, means, width, yerr=errors, capsize=5, label='Country 1 City 4')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Metrics')
ax.set_ylabel('Scores')
ax.set_title('Scores by metric Country 1 City 4')
ax.set_xticks(x)
ax.set_xticklabels(metrics)
ax.legend()

# Function to add labels on bars
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(round(height, 3)),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects)

fig.tight_layout()

plt.show()

# %% [markdown]
# Country: 0, 1
#
# City: 0, 1, 2, 4

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data provided
metrics = ['accuracy_score', 'f1_score', 'precision_score', 'recall_score']

# Means and standard deviations for each dataset
means_0_0 = [0.7860229, 0.7750206, 0.7723335, 0.7860229]
stds_0_0 = [0.0214483, 0.0223657, 0.0219168, 0.0214483]
t_interval_0_0 = [0.8455729869 - mean for mean in means_0_0]

means_0_1 = [0.7077301, 0.7025909, 0.7067849, 0.7077301]
stds_0_1 = [0.0421701, 0.0445236, 0.0479883, 0.0421701]
t_interval_0_1 = [0.8248130034 - mean for mean in means_0_1]

means_0_2 = [0.7549491, 0.7494852, 0.7520444, 0.7549491]
stds_0_2 = [0.0220701, 0.0233196, 0.0210119, 0.0220701]
t_interval_0_2 = [0.816225608 - mean for mean in means_0_2]

means_1_0 = [0.7050824, 0.7014499, 0.7058068, 0.7050824]
stds_1_0 = [0.019814, 0.0194728, 0.0185834, 0.019814]
t_interval_1_0 = [0.7600947968 - mean for mean in means_1_0]

means_1_2 = [0.6748362, 0.6710036, 0.677202, 0.6748362]
stds_1_2 = [0.0198673, 0.019282, 0.0204394, 0.0198673]
t_interval_1_2 = [0.7299967761 - mean for mean in means_1_2]

means_1_4 = [0.6793103, 0.6604772, 0.6836487, 0.6793103]
stds_1_4 = [0.0187587, 0.0222506, 0.0272602, 0.0187587]
t_interval_1_4 = [0.7313927574 - mean for mean in means_1_4]

# Calculate the error bars (using confidence intervals as error)
errors_0_0 = t_interval_0_0
errors_0_1 = t_interval_0_1
errors_0_2 = t_interval_0_2
errors_1_0 = t_interval_1_0
errors_1_2 = t_interval_1_2
errors_1_4 = t_interval_1_4

x = np.arange(len(metrics))  # the label locations
width = 0.15  # the width of the bars

fig, ax = plt.subplots(figsize=(14, 8))

rects1 = ax.bar(x - width*2, means_0_0, width, label='Dataset 0_0', yerr=errors_0_0, capsize=5)
rects2 = ax.bar(x - width, means_0_1, width, label='Dataset 0_1', yerr=errors_0_1, capsize=5)
rects3 = ax.bar(x, means_0_2, width, label='Dataset 0_2', yerr=errors_0_2, capsize=5)
rects4 = ax.bar(x + width, means_1_0, width, label='Dataset 1_0', yerr=errors_1_0, capsize=5)
rects5 = ax.bar(x + width*2, means_1_2, width, label='Dataset 1_2', yerr=errors_1_2, capsize=5)
rects6 = ax.bar(x + width*3, means_1_4, width, label='Dataset 1_4', yerr=errors_1_4, capsize=5)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Metrics')
ax.set_ylabel('Scores')
ax.set_title('Scores by metric and dataset')
ax.set_xticks(x)
ax.set_xticklabels(metrics)
ax.legend()

# Function to add labels on bars
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(round(height, 3)),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)
autolabel(rects5)
autolabel(rects6)

fig.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Dados fornecidos
metrics = ['accuracy_score', 'f1_score', 'precision_score', 'recall_score']

# Médias e desvios padrão para cada dataset
means_0_0 = [0.7860229, 0.7750206, 0.7723335, 0.7860229]
t_interval_0_0 = [0.8455729869 - mean for mean in means_0_0]

means_0_1 = [0.7077301, 0.7025909, 0.7067849, 0.7077301]
t_interval_0_1 = [0.8248130034 - mean for mean in means_0_1]

means_0_2 = [0.7549491, 0.7494852, 0.7520444, 0.7549491]
t_interval_0_2 = [0.816225608 - mean for mean in means_0_2]

means_1_0 = [0.7050824, 0.7014499, 0.7058068, 0.7050824]
t_interval_1_0 = [0.7600947968 - mean for mean in means_1_0]

means_1_2 = [0.6748362, 0.6710036, 0.677202, 0.6748362]
t_interval_1_2 = [0.7299967761 - mean for mean in means_1_2]

means_1_4 = [0.6793103, 0.6604772, 0.6836487, 0.6793103]
t_interval_1_4 = [0.7313927574 - mean for mean in means_1_4]

# Calcular as barras de erro (usando os intervalos de confiança como erro)
errors_0_0 = t_interval_0_0
errors_0_1 = t_interval_0_1
errors_0_2 = t_interval_0_2
errors_1_0 = t_interval_1_0
errors_1_2 = t_interval_1_2
errors_1_4 = t_interval_1_4

x = np.arange(len(metrics))  # Locais dos rótulos
width = 0.15  # Largura das barras

fig, ax = plt.subplots(figsize=(14, 8))

# Criar as barras para cada conjunto de dados com os intervalos de confiança
rects1 = ax.bar(x - width*2, means_0_0, width, label='Dataset 0_0', yerr=errors_0_0, capsize=5)
rects2 = ax.bar(x - width, means_0_1, width, label='Dataset 0_1', yerr=errors_0_1, capsize=5)
rects3 = ax.bar(x, means_0_2, width, label='Dataset 0_2', yerr=errors_0_2, capsize=5)
rects4 = ax.bar(x + width, means_1_0, width, label='Dataset 1_0', yerr=errors_1_0, capsize=5)
rects5 = ax.bar(x + width*2, means_1_2, width, label='Dataset 1_2', yerr=errors_1_2, capsize=5)
rects6 = ax.bar(x + width*3, means_1_4, width, label='Dataset 1_4', yerr=errors_1_4, capsize=5)

# Adicionar rótulos, título e personalizar rótulos do eixo x, etc.
ax.set_xlabel('Metrics')
ax.set_ylabel('Scores')
ax.set_title('Scores by Metric and Dataset')
ax.set_xticks(x)
ax.set_xticklabels(metrics)
ax.legend()

# Função para adicionar os rótulos nas barras, incluindo os valores dos intervalos de confiança
def autolabel(rects, errors):
    for rect, err in zip(rects, errors):
        height = rect.get_height()
        ax.annotate(f'{height:.3f}\n±{err:.3f}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 pontos de deslocamento vertical
                    textcoords="offset points",
                    ha='center', va='bottom')

# Adicionar rótulos nas barras com os valores de confiança
autolabel(rects1, errors_0_0)
autolabel(rects2, errors_0_1)
autolabel(rects3, errors_0_2)
autolabel(rects4, errors_1_0)
autolabel(rects5, errors_1_2)
autolabel(rects6, errors_1_4)

fig.tight_layout()

plt.show()

# %% [markdown]
# Country: 0 e 1
#
# City: ALL

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data provided
metrics = ['accuracy_score', 'f1_score', 'precision_score', 'recall_score']
means_0 = [0.738072, 0.7320152, 0.73579, 0.738072]
stds_0 = [0.0138355, 0.0153487, 0.0115635, 0.0138355]
t_interval_0 = [0.776485479, 0.7746301248, 0.7678954874, 0.776485479]

means_1 = [0.6906785, 0.6849193, 0.6908531, 0.6906785]
stds_1 = [0.0065842, 0.0069235, 0.0075631, 0.0065842]
t_interval_1 = [0.7089591624, 0.7041419906, 0.7118516999, 0.7089591624]

# Calculate the error bars (using standard deviation as error)
errors_0 = [t - m for m, t in zip(means_0, t_interval_0)]
errors_1 = [t - m for m, t in zip(means_1, t_interval_1)]

x = np.arange(len(metrics))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(10, 6))
rects1 = ax.bar(x - width/2, means_0, width, label='Country 0', yerr=errors_0, capsize=5)
rects2 = ax.bar(x + width/2, means_1, width, label='Country 1', yerr=errors_1, capsize=5)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Metrics')
ax.set_ylabel('Scores')
ax.set_title('Scores by metric and dataset')
ax.set_xticks(x)
ax.set_xticklabels(metrics)
ax.legend()

# Function to add labels on bars
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(round(height, 2)),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()
