# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

file_path = '0_0.csv' 
df = pd.read_csv(file_path, index_col=0)

df = df.transpose()

df.reset_index(inplace=True)
df.rename(columns={'index': 'Classifier'}, inplace=True)

print("Transposed DataFrame:")
print(df)

print("\nDescriptive Statistics:")
print(df.describe())
# Out:
# Transposed DataFrame:
# Classifier                Classifier  Accuracy  F1-Score  Precision  Recall
# 0           best of M1 and M2 models     0.700     0.690      0.660   0.760
# 1                         HIVECOTEV2     0.768     0.754      0.751   0.768
# 2                              Hydra     0.780     0.765      0.765   0.780
# 3                        MultiRocket     0.721     0.729      0.753   0.721
# 4                   Proximity Forest       NaN       NaN        NaN     NaN
# 5                   Elastic Ensemble     0.710     0.712      0.719   0.710
# 6                       Fresh Prince     0.542     0.541      0.543   0.542
# 7                            TSFresh     0.747     0.743      0.745   0.747
# 8                              DrCIF     0.738     0.735      0.735   0.738
# 9                              rSTSF     0.779     0.772      0.773   0.779
# 10                              RDST     0.781     0.764      0.761   0.781
# 11                             MrSQM     0.761     0.760      0.763   0.761
# 12                          Weasel-D     0.786     0.775      0.772   0.786
# 13                               TDE     0.712     0.713      0.726   0.712
# 14                    Inception Time     0.325     0.284      0.525   0.325
# 15                            ResNet       NaN       NaN        NaN     NaN
# 16                          ridge_cv     0.786     0.772      0.769   0.786
#
# Descriptive Statistics:
# Classifier   Accuracy   F1-Score  Precision     Recall
# count       15.000000  15.000000  15.000000  15.000000
# mean         0.709067   0.700600   0.717333   0.713067
# std          0.122775   0.129143   0.079845   0.123434
# min          0.325000   0.284000   0.525000   0.325000
# 25%          0.711000   0.712500   0.722500   0.716500
# 50%          0.747000   0.743000   0.751000   0.760000
# 75%          0.779500   0.764500   0.764000   0.779500
# max          0.786000   0.775000   0.773000   0.786000

# %%
metrics = ['Accuracy', 'Precision', 'Recall', 'F1-Score']
df['Mean_Rank'] = df[metrics].mean(axis=1)
df = df.sort_values(by='F1-Score', ascending=False)

# %%
print("\nRanked DataFrame:")
print(df[['Classifier', 'F1-Score']])
# Out:
# Ranked DataFrame:
# Classifier                Classifier  F1-Score
# 12                          Weasel-D     0.775
# 9                              rSTSF     0.772
# 16                          ridge_cv     0.772
# 2                              Hydra     0.765
# 10                              RDST     0.764
# 11                             MrSQM     0.760
# 1                         HIVECOTEV2     0.754
# 7                            TSFresh     0.743
# 8                              DrCIF     0.735
# 3                        MultiRocket     0.729
# 13                               TDE     0.713
# 5                   Elastic Ensemble     0.712
# 0           best of M1 and M2 models     0.690
# 6                       Fresh Prince     0.541
# 14                    Inception Time     0.284
# 4                   Proximity Forest       NaN
# 15                            ResNet       NaN

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Classifier', y='F1-Score', data=df)
plt.xticks(rotation=90)
plt.title('Classifier F1-Score Comparison')
plt.show()

# %%
# Step 9: Plot correlation matrix
plt.figure(figsize=(10, 6))
sns.heatmap(df[metrics].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
