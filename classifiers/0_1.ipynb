# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

file_path = '0_1.csv' 
df = pd.read_csv(file_path, index_col=0)

df = df.transpose()

df.reset_index(inplace=True)
df.rename(columns={'index': 'Classifier'}, inplace=True)

print("Transposed DataFrame:")
print(df)

print("\nDescriptive Statistics:")
print(df.describe())
# Out:
# Transposed DataFrame:
# Classifier                Classifier  Accuracy  F1-Score  Precision  Recall
# 0           best of M1 and M2 models     0.700     0.690      0.660   0.760
# 1                         HIVECOTEV2     0.680     0.670      0.676   0.680
# 2                              Hydra     0.700     0.693      0.699   0.700
# 3                        MultiRocket     0.693     0.694      0.701   0.693
# 4                   Proximity Forest       NaN       NaN        NaN     NaN
# 5                   Elastic Ensemble     0.641     0.642      0.648   0.641
# 6                       Fresh Prince     0.567     0.565      0.568   0.567
# 7                            TSFresh     0.690     0.690      0.693   0.690
# 8                              DrCIF     0.665     0.664      0.668   0.665
# 9                              rSTSF     0.701     0.697      0.698   0.701
# 10                              RDST     0.699     0.691      0.697   0.699
# 11                             MrSQM     0.658     0.656      0.657   0.658
# 12                          Weasel-D     0.708     0.703      0.707   0.708
# 13                               TDE     0.712     0.711      0.723   0.712
# 14                    Inception Time     0.164     0.079      0.427   0.164
# 15                            ResNet       NaN       NaN        NaN     NaN
# 16                          ridge_cv     0.696     0.681      0.684   0.696
#
# Descriptive Statistics:
# Classifier   Accuracy   F1-Score  Precision     Recall
# count       15.000000  15.000000  15.000000  15.000000
# mean         0.644933   0.635067   0.660400   0.648933
# std          0.138033   0.157884   0.074201   0.140589
# min          0.164000   0.079000   0.427000   0.164000
# 25%          0.661500   0.660000   0.658500   0.661500
# 50%          0.693000   0.690000   0.684000   0.693000
# 75%          0.700000   0.693500   0.698500   0.700500
# max          0.712000   0.711000   0.723000   0.760000

# %%
metrics = ['Accuracy', 'Precision', 'Recall', 'F1-Score']
df['Mean_Rank'] = df[metrics].mean(axis=1)
df = df.sort_values(by='F1-Score', ascending=False)

# %%
print("\nRanked DataFrame:")
print(df[['Classifier', 'F1-Score']])
# Out:
# Ranked DataFrame:
# Classifier                Classifier  F1-Score
# 13                               TDE     0.711
# 12                          Weasel-D     0.703
# 9                              rSTSF     0.697
# 3                        MultiRocket     0.694
# 2                              Hydra     0.693
# 10                              RDST     0.691
# 0           best of M1 and M2 models     0.690
# 7                            TSFresh     0.690
# 16                          ridge_cv     0.681
# 1                         HIVECOTEV2     0.670
# 8                              DrCIF     0.664
# 11                             MrSQM     0.656
# 5                   Elastic Ensemble     0.642
# 6                       Fresh Prince     0.565
# 14                    Inception Time     0.079
# 4                   Proximity Forest       NaN
# 15                            ResNet       NaN

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Classifier', y='F1-Score', data=df)
plt.xticks(rotation=45)
plt.title('Classifier F1-Score Comparison')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df[metrics].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
